# %%
import secrets


def generate_device_id(length=16):
    return secrets.token_hex(length // 2)


device_id = generate_device_id()
print(device_id)
# Out:
# 40d0668105849924

# %%
import time

timestamp_ms = int(time.time() * 1000)
print(timestamp_ms)
# Out:
# 1743907580003

# %%
import requests
import time
import secrets


# Generate dynamic deviceId and timestamp
def generate_device_id(length=16):
    return secrets.token_hex(length // 2)


device_id = generate_device_id()
timestamp_ms = int(time.time() * 1000)

# Parameters and headers
params = {
    "type": "sdk-dci",
    "starttime": timestamp_ms,
    "systemVersion": "10",
    "model": "One",
    "deviceHardwareType": "qcom",
    "appIdentifier": "com.meijer.mobile.meijer",
    "deviceId": device_id,
}

headers = {
    "User-Agent": "Akamai BMPSDK/3.3.9 (Android; 10; HTC; One; en)",
    "Host": "id.meijer.com",
    "Connection": "Keep-Alive",
    "Accept-Encoding": "gzip",
    "Content-Length": "0",
}

# Making the GET request
response = requests.get(
    "https://id.meijer.com/_bm/get_params", params=params, headers=headers
)

print(response.status_code)
print(response.json())
# Out:
# 200
# {'serversidesignal': 'AAQAAAAD%2f%2f%2f%2f%2f6u7qa8n1u+%2fKPbzrfJspirdQ27YTMGMO951i3S8TI4H%2fEv+dvpfodj5o2GuUmJYGb3sibLKoihrW6vA3sda2yg8EF+Z9ziHj%2fsUDCfi1CepFKjy5I5mUNWzPknx4aQCXE5GP5vga5TwrevIjyeUcqX5IFUU3WYdp0rnp9f4T%2fWTaH474ivlobf+OIoN%2fXiGRJzr54g6mpzUF5rh2n2ISJ2gYDgGNXulftGbktYwLfNI1A34u04pSTugIEPNndWnbRNGmhsxlY5glZuJNWJ2FfeT9p3F22RVS2o%3d'}

# %%
serversidesignal = response.json()["serversidesignal"]

# %%
from urllib.parse import unquote

# %%
decoded_str = unquote(serversidesignal)
decoded_str
# Out:
# ''

# %%
import requests
import secrets
import time


# Generate dynamic values
def generate_device_id(length=16):
    return secrets.token_hex(length // 2)


device_id = generate_device_id()
timestamp_ms = int(time.time() * 1000)

# Parameters
params = {
    "os": "android",
    "starttime": timestamp_ms,
    "systemVersion": "10",
    "model": "One",
    "deviceHardwareType": "qcom",
    "appIdentifier": "com.meijer.mobile.meijer",
    "deviceId": device_id,
    "serverSideSignal": decoded_str,
}

# Headers
headers = {
    "pragma": "no-cache",
    "cache-control": "no-cache",
    "user-agent": "Mozilla/5.0 (Linux; Android 10; One Build/QQ3A.200705.002; wv) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/81.0.4044.138 Mobile Safari/537.36",
    "accept": "*/*",
    "x-requested-with": "com.meijer.mobile.meijer",
    "sec-fetch-site": "cross-site",
    "sec-fetch-mode": "no-cors",
    "sec-fetch-dest": "script",
    "accept-encoding": "gzip, deflate",
    "accept-language": "en-US,en;q=0.9",
    "content-length": "0",
}

# Perform the request
response = requests.get(
    "https://id.meijer.com/_sec/sdk_challenge.js", params=params, headers=headers
)

print(response.status_code)
print(response.text)
# Out:
# 200
# (function nzAhTRhkbS(){Z();var H;pG();AG();var sl=function(Bl,dl){return Bl>dl;};var fl=function(){return gl.apply(this,[dc,arguments]);};function P7(a){return a.length;}var tl=function Cl(Ml,Al){var pl=Cl;while(Ml!=fc){switch(Ml){case gc:{Ml=fc;for(var bl=hl;Sl(bl,Vl.length);++bl){H[Vl[bl]]=function(){var Ll=Vl[bl];return function(Kl,Rl,nl){var Er=Ur.apply(null,[Kl,Rl,xr(xr(cr))]);;H[Ll]=function(){return Er;};return Er;};}();}}break;case tc:{Ml=fc;for(var Hr=hl;Sl(Hr,kr.length);++Hr){H[kr[Hr]]=function(){var Wr=kr[Hr];return function(lr,rr,Zr){var zr=mr(lr,rr,Dr);;H[Wr]=function(){return zr;};return zr;};}();}}break;case Mc:{Ml+=Cc;return Jr;}break;case pc:{var Or=Nr([],[]);Ml=Ac;Tr=Nr(Pr(Yr,Qr[Pr(Qr.length,cr)]),N);}break;case Rc:{Ml+=bc;var wr=Al[Qc];if(vr(wr,hc)){return U[Xr[Ir]][Xr[Gr]](wr);}else{wr-=Sc;return U[Xr[Ir]][Xr[Gr]][Xr[Fr]](null,[Nr(jr(wr,qr),Vc),Nr(sr(wr,Lc),Kc)]);}}break;case EH:{return gl(nc,[Br]);}break;case xH:{var dr=fr[gr];for(var tr=Pr(dr.length,cr);Cr(tr,hl);tr--){var Mr=sr(Nr(Pr(Nr(tr,Ar),Qr[Pr(Qr.length,cr)]),N),pr.length);var br=hr(dr,tr);var Sr=hr(pr,Mr);Br+=Cl(Rc,[Vr(Lr(Vr(br,Sr)),Kr(br,Sr))]);}Ml-=UH;}break;case cH:{Ml=fc;while(Sl(Rr,nr.length)){H[nr[Rr]]=function(){var EZ=nr[Rr];return function(UZ,xZ){var cZ=HZ(UZ,xZ);;H[EZ]=function(){return cZ;};return cZ;};}();++Rr;}}break;case HH:{Ml=fc;return Or;}break;case Ac:{Ml=HH;while(sl(kZ,hl)){if(WZ(lZ[Xr[rZ]],U[Xr[cr]])&&Cr(lZ,ZZ[Xr[hl]])){if(zZ(ZZ,mZ)){Or+=Cl(Rc,[Tr]);}return Or;}if(DZ(lZ[Xr[rZ]],U[Xr[cr]])){var JZ=OZ[ZZ[lZ[hl]][hl]];var NZ=Cl.call(null,kH,[lZ[cr],JZ,TZ,Pr(Nr(Tr,Qr[Pr(Qr.length,cr)]),N),kZ]);Or+=NZ;lZ=lZ[hl];kZ-=PZ(WH,[NZ]);}else if(DZ(ZZ[lZ][Xr[rZ]],U[Xr[cr]])){var JZ=OZ[ZZ[lZ][hl]];var NZ=Cl(kH,[hl,JZ,xr(xr([])),Pr(Nr(Tr,Qr[Pr(Qr.length,cr)]),N),kZ]);Or+=NZ;kZ-=PZ(WH,[NZ]);}else{Or+=Cl(Rc,[Tr]);Tr+=ZZ[lZ];--kZ;};++lZ;}}break;case lH:{Ml=cH;var nr=Al[Qc];YZ();var Rr=hl;}break;case rH:{var Ar=Al[Qc];var gr=Al[wc];Ml=xH;var QZ=Al[vc];var pr=fr[wZ];var Br=Nr([],[]);}break;case kH:{var lZ=Al[Qc];var ZZ=Al[wc];var vZ=Al[vc];var Yr=Al[Xc];Ml+=ZH;var kZ=Al[Ic];if(DZ(typeof ZZ,Xr[XZ])){ZZ=mZ;}}break;case zH:{return ['Y4','r4','z4','m4','V','P4','U4'];}break;case DH:{Ml-=mH;if(Sl(IZ,GZ.length)){do{var FZ=hr(GZ,IZ);var jZ=hr(HZ.Nc,qZ++);Jr+=Cl(Rc,[Kr(Vr(Lr(FZ),jZ),Vr(Lr(jZ),FZ))]);IZ++;}while(Sl(IZ,GZ.length));}}break;case JH:{var Vl=Al[Qc];sZ();Ml=gc;}break;case Xc:{var BZ=Al[Qc];HZ=function(dZ,fZ){return Cl.apply(this,[OH,arguments]);};return YZ(BZ);}break;case Fc:{return ['X','c4','D4','T4','L','G','K'];}break;case TH:{gZ=[tZ,CZ(MZ),AZ,CZ(pZ),CZ(tZ),bZ,CZ(Ir),Gr,Ir,CZ(hZ),SZ,VZ,CZ(XZ),LZ,CZ(Fr),CZ(KZ),pZ,CZ(RZ),VZ,nZ,Ez,CZ(KZ),CZ(Uz),xz,Gr,Fr,cz,CZ(Hz),kz,CZ(LZ),CZ(LZ),Ez,Ir,tZ,MZ,CZ(Hz),LZ,Hz,CZ(wZ),tZ,CZ(AZ),CZ(Wz),lz,lz,CZ(cz),kz,CZ(cz)];Ml+=NH;}break;case OH:{var rz=Al[Qc];var Zz=Al[wc];var Jr=Nr([],[]);var qZ=sr(Nr(Pr(Zz,Qr[Pr(Qr.length,cr)]),N),zz);var GZ=mz[rz];Ml=DH;var IZ=hl;}break;case YH:{Dz=[Ez,MZ,CZ(LZ),CZ(LZ),pZ,CZ(AZ),cr,qr,CZ(MZ),CZ(pZ),KZ,CZ(XZ),CZ(cr),CZ(cr),Gr,CZ(KZ),KZ,CZ(Jz),MZ,CZ(tZ),Jz,pZ,cr,CZ(qr),Ir,CZ(cr),CZ(tZ),cz,Ez,CZ(zz),CZ(kz),CZ(XZ),Ez,CZ(rZ),cz,CZ(Jz),Oz,CZ(Hz),CZ(Jz),AZ,CZ(pZ),Ez,Ir,CZ(lz),Nz,CZ(cz),cr];Ml+=PH;}break;case Bc:{var kr=Al[Qc];Tz();Ml+=QH;}break;case wH:{return ['l4','W4','x4','Q','N4','I'];}break;}}};var Nr=function(Pz,Yz){return Pz+Yz;};var PZ=function Qz(wz,vz){var Xz=Qz;while(wz!=vH){switch(wz){case XH:{wz+=Xc;return Iz=U[H.UU(Gz,Gr,xr([]))][H.A4(Fz,jz,Gr)][H.OU.call(null,qz,zz,sz)].call(Bz,dz),Qr.pop(),Iz;}break;case GH:{Qr=fz();gz();wz-=IH;tz.call(this,Fc,[gl(Qc,[])]);Cz();tl.call(this,JH,[gl(jc,[])]);Mz();}break;case FH:{wz=vH;Qr.pop();}break;case dH:{gl(ZH,[]);Az(jH,[tl(zH,[])]);tl(TH,[]);wz+=qH;Az(sH,[tl(wH,[])]);tl(YH,[]);tz(BH,[tl(Fc,[])]);}break;case tH:{wz=FH;pz[H.R4(bz,RW)]=hz,pz[H.n4.apply(null,[Fr,Sz,Vz])]=Lz,pz[H.EU(Kz,hZ,cr)]=function(Rz,nz,E9){Qr.push(U9);pz[H.Q.apply(null,[x9,c9,H9,k9,hl,cr])](Rz,nz)||U[H.UU(W9,Gr,kz)][H.xU(l9,r9,Z9)](Rz,nz,Qz(fH,[H.X.call(null,qr,z9,hl ...
