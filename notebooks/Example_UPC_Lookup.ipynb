# %% [markdown]
# # UPC Lookup
#
# Look up Meijer UPCs and return data.

# %%
import sys, os
import pandas as pd

sys.path.append(os.path.abspath("meijer"))

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Create ```Meijer``` instance.

# %%
from meijer import Meijer

# m = Meijer("<mperks-email>|<mperks-password>") # Password, not PIN.
# If no meijer_api_key is specified the class looks at the ```MEIJER_API_KEY``` environmental variable.
m = Meijer()
self = m
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from meijer import Meijer
#       3 # m = Meijer("<mperks-email>|<mperks-password>") # Password, not PIN.
#       4 # If no meijer_api_key is specified the class looks at the ```MEIJER_API_KEY``` environmental variable.
#       5 m = Meijer()
#
# File /projects/python_Meijer/meijer/__init__.py:13
#       9 __author__ = "Meijer API Client Contributors"
#      11 # Import main client
#      12 # Import CLI functionality
# ---> 13 from .cli import cli
#      14 from .client import Meijer
#      16 # Import exceptions
#
# File /projects/python_Meijer/meijer/cli/__init__.py:7
#       1 """
#       2 Meijer CLI Tool
#       3
#       4 A comprehensive command-line interface for managing Meijer shopping lists.
#       5 """
# ----> 7 from .main import cli
#       9 __all__ = ["cli"]
#
# File /projects/python_Meijer/meijer/cli/main.py:26
#       2 """
#       3 /**
#       4  * This code written by Claude Sonnet 4 (claude-3-5-sonnet-20241022)
#    (...)     21 A comprehensive command-line interface for managing Meijer shopping lists.
#      22 """
#      24 import click
# ---> 26 from .commands import (
#      27     ad_command,
#      28     auth_command,
#      29     cart_group,
#      30     coupons_group,
#      31     gas_command,
#      32     list_group,
#      33     settings_group,
#      34     status_command,
#      35 )
#      38 @click.group()
#      39 @click.version_option(version="1.0.0", prog_name="meijer")
#      40 def cli():
#      41     """
#      42     🛒 Meijer Shopping List CLI Tool
#      43
#    (...)     54     • gas - Show gas station information
#      55     """
#
# File /projects/python_Meijer/meijer/cli/commands.py:13
#       9 from typing import Optional
#      11 import click
# ---> 13 from .utils import (
#      14     add_items_from_file,
#      15     display_items_table,
#      16     export_to_csv,
#      17     export_to_json,
#      18     export_to_text,
#      19     get_meijer_client,
#      20     import_from_csv,
#      21     import_from_json,
#      22     import_from_text,
#      23 )
#      26 # Shopping List Commands
#      27 @click.group()
#      28 def list_group():
#
# File /projects/python_Meijer/meijer/cli/utils.py:14
#      10 from typing import List, TextIO
#      12 import click
# ---> 14 from ..client import Meijer
#      17 def get_meijer_client() -> Meijer:
#      18     """
#      19     Get an authenticated Meijer client instance.
#      20
#    (...)     25         click.ClickException: If authentication fails
#      26     """
#
# File /projects/python_Meijer/meijer/client.py:19
#      17 from .feedback import MeijerFeedback
#      18 from .models import ListItem, MeijerCoupon, MeijerItem, SearchResult, Store
# ---> 19 from .mperks import EarnedReward, MCardInfo, MPerksEarnedRewards
#      20 from .product_operations import ProductOperations
#      21 from .search import Search
#
# File /projects/python_Meijer/meijer/mperks.py:71
#      53         result = {
#      54             "id": self.id,
#      55             "title": self.title,
#    (...)     66             "termsConditions": self.terms_conditions,
#      67         }
#      68         return {k: v for k, v in result.items() if v is not None}
# ---> 71 @dataclass
#      72 class RewardCoupon:
#      73     """Represents a reward coupon that can be purchased with points."""
#      75     coupon_id: int
#
# File /usr/lib/python3.12/dataclasses.py:1268, in dataclass(cls, init, repr, eq, order, unsafe_hash, frozen, match_args, kw_only, slots, weakref_slot)
#    1265     return wrap
#    1267 # We're called as @dataclass without parens.
# -> 1268 return wrap(cls)
#
# File /usr/lib/python3.12/dataclasses.py:1258, in dataclass.<locals>.wrap(cls)
#    1257 def wrap(cls):
# -> 1258     return _process_class(cls, init, repr, eq, order, unsafe_hash,
#    1259                           frozen, match_args, kw_only, slots,
#    1260                           weakref_slot)
#
# File /usr/lib/python3.12/dataclasses.py:1063, in _process_class(cls, init, repr, eq, order, unsafe_hash, frozen, match_args, kw_only, slots, weakref_slot)
#    1058 if init:
#    1059     # Does this class have a post-init function?
#    1060     has_post_init = hasattr(cls, _POST_INIT_NAME)
#    1062     _set_new_attribute(cls, '__init__',
# -> 1063                        _init_fn(all_init_fields,
#    1064                                 std_init_fields,
#    1065                                 kw_only_init_fields,
#    1066                                 frozen,
#    1067                                 has_post_init,
#    1068                                 # The name to use for the "self"
#    1069                                 # param in __init__.  Use "self"
#    1070                                 # if possible.
#    1071                                 '__dataclass_self__' if 'self' in fields
#    1072                                         else 'self',
#    1073                                 globals,
#    1074                                 slots,
#    1075                       ))
#    1077 # Get the fields as a list, and include only real fields.  This is
#    1078 # used in all of the following methods.
#    1079 field_list = [f for f in fields.values() if f._field_type is _FIELD]
#
# File /usr/lib/python3.12/dataclasses.py:585, in _init_fn(fields, std_fields, kw_only_fields, frozen, has_post_init, self_name, globals, slots)
#     583             seen_default = True
#     584         elif seen_default:
# --> 585             raise TypeError(f'non-default argument {f.name!r} '
#     586                             'follows default argument')
#     588 locals = {f'__dataclass_type_{f.name}__': f.type for f in fields}
#     589 locals.update({
#     590     '__dataclass_HAS_DEFAULT_FACTORY__': _HAS_DEFAULT_FACTORY,
#     591     '__dataclass_builtins_object__': object,
#     592 })
#
# TypeError: non-default argument 'point_cost' follows default argument

# %%
m.get_upc?
# Out:
# Object `m.get_upc` not found.

# %% [markdown]
# # Call ```.get_upc()```
#
# Defaults:
#
# - upc='4125010200' [Meijer Vitamin D milk]
# - storeID='226' [Rockford Meijer Store, chosen at random]

# %%
results = m.get_upc()
assert results["meta"]["totalResults"] == 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 results = m.get_upc()
#       2 assert results["meta"]["totalResults"] == 1
#
# NameError: name 'm' is not defined

# %%
results["upcs"][0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 results["upcs"][0]
#
# NameError: name 'results' is not defined

# %%
upcs = m.get_upc(upc=41250102)
upcs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 upcs = m.get_upc(upc=41250102)
#       2 upcs
#
# NameError: name 'm' is not defined

# %% [markdown]
# Get everything Meijer sells, empty query is a wildcard(?)

# %%
upcs = m.get_upc(upc="")
print(f"Found {upcs['meta']['totalResults']} upcs")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 upcs = m.get_upc(upc="")
#       2 print(f"Found {upcs['meta']['totalResults']} upcs")
#
# NameError: name 'm' is not defined

# %%
upcs.keys()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 upcs.keys()
#
# NameError: name 'upcs' is not defined

# %%
len(upcs["upcs"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 len(upcs["upcs"])
#
# NameError: name 'upcs' is not defined

# %% [markdown]
# # List all Stores

# %%
stores = m.stores()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 stores = m.stores()
#
# NameError: name 'm' is not defined

# %% [markdown]
# # Find All Vitamin D Milk Prices

# %%
data = list()
for store in stores:
    upc_data = m.get_upc(storeID=store["unitid"])
    if len(upc_data["upcs"]) > 0:
        try:
            tmp = {
                "storeid": store["unitid"],
                "latitude": store["latitude"],
                "longitude": store["longitude"],
                "MeijerVitaminD": upc_data["upcs"][0]["priceValue"],
            }
            data.append(tmp)
        except KeyError:
            pass
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 data = list()
# ----> 2 for store in stores:
#       3     upc_data = m.get_upc(storeID=store["unitid"])
#       4     if len(upc_data["upcs"]) > 0:
#
# NameError: name 'stores' is not defined

# %%
len(stores)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 len(stores)
#
# NameError: name 'stores' is not defined

# %%
len(data)
# Out:
# 0

# %% [markdown]
# # Convert Pricing Data to pandas DataFrame

# %%
df = pd.DataFrame(data)

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

# %%
ax = df.MeijerVitaminD.hist(bins=20)
plt.title("Meijer Vitamin D Milk Histogram")
plt.xlabel("Price of Milk")
plt.ylabel("Number of Stores")
ax.xaxis.set_major_formatter(mtick.StrMethodFormatter("${x:,.2f}"))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/tmp/ipykernel_254866/11536439.py in ?()
# ----> 1 ax = df.MeijerVitaminD.hist(bins=20)
#       2 plt.title("Meijer Vitamin D Milk Histogram")
#       3 plt.xlabel("Price of Milk")
#       4 plt.ylabel("Number of Stores")
#
# /projects/python_Meijer/venv/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'MeijerVitaminD'

# %% [markdown]
# ## Gas Prices

# %%
stores = m.stores()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 stores = m.stores()
#
# NameError: name 'm' is not defined

# %%
data = list()
for store in stores:
    upc_data = m.get_upc(storeID=store["unitid"])
    if len(upc_data["upcs"]) > 0:
        tmp = {
            "storeid": store["unitid"],
            "latitude": store["latitude"],
            "longitude": store["longitude"],
            "MeijerVitaminD": upc_data["upcs"][0]["priceValue"],
        }
        if store["FuelPrices"] is not None:
            for fuel_price in store["FuelPrices"]:
                fuel_type = fuel_price["FuelType"].split("-")[0]
                fuel_price = fuel_price["FuelPrice"]
                tmp[fuel_type] = fuel_price
        data.append(tmp)
df = pd.DataFrame(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 data = list()
# ----> 2 for store in stores:
#       3     upc_data = m.get_upc(storeID=store["unitid"])
#       4     if len(upc_data["upcs"]) > 0:
#
# NameError: name 'stores' is not defined

# %% [markdown]
# ## Gas Pricing: Unleaded vs Midrange

# %%
df.plot.scatter(x="UNL", y="MID")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df.plot.scatter(x="UNL", y="MID")
#
# File /projects/python_Meijer/venv/lib/python3.12/site-packages/pandas/plotting/_core.py:1748, in PlotAccessor.scatter(self, x, y, s, c, **kwargs)
#    1660 def scatter(
#    1661     self,
#    1662     x: Hashable,
#    (...)   1666     **kwargs,
#    1667 ) -> PlotAccessor:
#    1668     """
#    1669     Create a scatter plot with varying marker point size and color.
#    1670
#    (...)   1746         ...                       colormap='viridis')
#    1747     """
# -> 1748     return self(kind="scatter", x=x, y=y, s=s, c=c, **kwargs)
#
# File /projects/python_Meijer/venv/lib/python3.12/site-packages/pandas/plotting/_core.py:975, in PlotAccessor.__call__(self, *args, **kwargs)
#     973 if kind in self._dataframe_kinds:
#     974     if isinstance(data, ABCDataFrame):
# --> 975         return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     976     else:
#     977         raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# File /projects/python_Meijer/venv/lib/python3.12/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File /projects/python_Meijer/venv/lib/python3.12/site-packages/pandas/plotting/_matplotlib/core.py:499, in MPLPlot.generate(self)
#     497 @final
#     498 def generate(self) -> None:
# --> 499     self._compute_plot_data()
#     500     fig = self.fig
#     501     self._make_plot(fig)
#
# File /projects/python_Meijer/venv/lib/python3.12/site-packages/pandas/plotting/_matplotlib/core.py:698, in MPLPlot._compute_plot_data(self)
#     696 # no non-numeric frames or series allowed
#     697 if is_empty:
# --> 698     raise TypeError("no numeric data to plot")
#     700 self.data = numeric_data.apply(type(self)._convert_to_ndarray)
#
# TypeError: no numeric data to plot

# %% [markdown]
# ## Price: Unleaded vs Whole Milk.

# %%
df.plot.scatter(x="UNL", y="MeijerVitaminD")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df.plot.scatter(x="UNL", y="MeijerVitaminD")
#
# File /projects/python_Meijer/venv/lib/python3.12/site-packages/pandas/plotting/_core.py:1748, in PlotAccessor.scatter(self, x, y, s, c, **kwargs)
#    1660 def scatter(
#    1661     self,
#    1662     x: Hashable,
#    (...)   1666     **kwargs,
#    1667 ) -> PlotAccessor:
#    1668     """
#    1669     Create a scatter plot with varying marker point size and color.
#    1670
#    (...)   1746         ...                       colormap='viridis')
#    1747     """
# -> 1748     return self(kind="scatter", x=x, y=y, s=s, c=c, **kwargs)
#
# File /projects/python_Meijer/venv/lib/python3.12/site-packages/pandas/plotting/_core.py:975, in PlotAccessor.__call__(self, *args, **kwargs)
#     973 if kind in self._dataframe_kinds:
#     974     if isinstance(data, ABCDataFrame):
# --> 975         return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     976     else:
#     977         raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# File /projects/python_Meijer/venv/lib/python3.12/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File /projects/python_Meijer/venv/lib/python3.12/site-packages/pandas/plotting/_matplotlib/core.py:499, in MPLPlot.generate(self)
#     497 @final
#     498 def generate(self) -> None:
# --> 499     self._compute_plot_data()
#     500     fig = self.fig
#     501     self._make_plot(fig)
#
# File /projects/python_Meijer/venv/lib/python3.12/site-packages/pandas/plotting/_matplotlib/core.py:698, in MPLPlot._compute_plot_data(self)
#     696 # no non-numeric frames or series allowed
#     697 if is_empty:
# --> 698     raise TypeError("no numeric data to plot")
#     700 self.data = numeric_data.apply(type(self)._convert_to_ndarray)
#
# TypeError: no numeric data to plot

# %%
import datetime

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2025, 8, 18, 23, 48, 8, 416043)
