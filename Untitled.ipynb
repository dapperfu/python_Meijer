xNum0gfaTpDDCC9K1ds0ETgu0I-zfH4qqTAfMXi9m3n3_8I6tnYMVDI3NLurWAKm2a2iNyaiCfJ2e-Y8NgHPgh8AdluvwO4HFiR0Ba2ygcK-SVgDXokvpLuKDMrMZHJ68zfZpmj7XAnhNuWlHIXvSgqAxJUpEi4mSec9m0IDWCA_yTS-t9kHDABgBTLvp7nmEBLSHeu4Pa3CXLmmiGDmaRESFTRtoR0ISIlwWEeKFld75wfMGcCo8DyMiAlAGEs7yL-pVha2aXOC2EDYub7PKzI8oLy7fDMijdQpvm5bVG0T8mnffy6w0fQko2c3oGDxUrw68Y3di82lz6wM_bCKaKRrGlkelFT7NJ0eHBdLag2Q5KdcSpHruTAGhUEMK5OUzDAQqCRFk3U-WtfZr1mqTewmhemOcjtVw6Np-l7eJ2q9NnahlHzOTPBcTJup1WtSrLkiDFrREHpkVsgn1--anAYsfupD1fH7uDXu-JxaNDgk9oj2rivdug_lhrypsUEr-nJK4kZB3-Bb-HDfBJr0HuCAmxWEoS3hQV8s87Dub2dLMG3Ml7MF3bSdG31EoGmrdYjuvAJ4w1mh0zZv19VufyZcUjvjLCVojJ2D8Q2XAWPhInhcEDWJ1LQ9sh8MVfrUl4zQk6R63CKXXmtxC8Ar2rbEsY8hNsV1Dmriw4L41m4mJZPIaNQFAPxLtU7pl5PhjHX0bqtSw_LxfpEsUbH6POIcBAantAH9U5YMu1OpxEXInqU2RHv9XvGgfFSYd1DgE9M2yzzJDdg0W1vQjpk1Ux1tcQUw6Ufc01W7qptGVwWA66py2Mr81k6TsXXEC33ZIVrPWCuJjLXItR6f_fsRLqUnjr0mW-oAagTu4MADmIvk0aR3isCUpbpyHhoRvqkE2bczCHIuLmDE4Zs.P05CWEzioG4VljCWMOmy0A"
}

# %%
import requests

url = "https://id.meijer.com/idp/idx/introspect"

headers = {
    "accept": "application/ion+json; okta-version=1.0.0",
    "x-okta-user-agent-extended": "okta-auth-js/7.11.0 okta-signin-widget-g3-7.29.1-g5868685",
    "user-agent": "Mozilla/5.0 (Linux; Android 10; K) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.0.0 Mobile Safari/537.36",
    "content-type": "application/ion+json; okta-version=1.0.0",
    "origin": "https://id.meijer.com",
    "x-requested-with": "com.duckduckgo.mobile.android",
    "sec-fetch-site": "same-origin",
    "sec-fetch-mode": "cors",
    "sec-fetch-dest": "empty",
    "accept-encoding": "gzip, deflate",
    "accept-language": "en-US,en;q=0.9",
}

# %%
response = requests.post(url, headers=headers, json=stateToken)

print(response.status_code)
# Out:
# 200

# %%
r = response.json()

# %%
r
# Out:
# {'version': '1.0.0',
# ...

# %%
r['remediation']["value"][0]["value"][1]["value"]
# Out:
# 'eyJ6aXAiOiJERUYiLCJhbGlhcyI6ImVuY3J5cHRpb25rZXkiLCJ2ZXIiOiIxIiwib2lkIjoiMDBvZW14bng4Q3NocE5WeVM2OTYiLCJlbmMiOiJBMjU2R0NNIiwiYWxnIjoiZGlyIn0..jDoi1xJUNTBjznN9.kWDr-jfmk1LM6gAOp3PnIaNu4Cuz8WTxXq4uI4SReAUhHOrvna8USmkc8mRu-HI66qH01QveiVfPYXxVpK7ZXXwJQS3-UnRtao1ZqMxhwh7zu8hh4rIFlJ8neeugLFucgN-imRHRP7sjucC3QHM_jK_zC6pmX8L_TH-CJkSUrtaVEfHeJ5N-xleFi6infSRVk9XFtICH6mMVWtN2LbcHLa21wn8OhQXpKcToFJfaFnCDcfoVuiJqGJhr2Vy_EbusOWjYNo9BDrtvTXVu9kF-yCAvGv2Hr-skeU4KK5-IVmhR8q4lYa5RuABcUqX0oxJK0d96YpZKRcbUBDHxkfta7o2NT7t1FDLOtNuIWmz3IrlYJMhSh60d5wvKMk102UnWoJoRFRR0JXnI5fj4p_Rl9PF_VO2K-3dZUtLy6tEuAJafg1vZof_LBltreZ5lxq6VMpBQyFccal36Lz8mlT1F2L2JWQBAePAqoJjWfpeLMhXcAsMfmN4sz9VBLtxLIDWv11vJEOhSbE1NmEv2PJIvprJVX9onPyXidMb5ESspozHaNf1P1r0R2F3yB3k2KJBS3ch3DHMR_qaVhtN9G6SpcTl1Npox52VilG6j-V1adMUm6b-Iv83sMflaAXdASswoKogrlxKunlXCvoLW1bPHzSekb3byYLh79eVoorCZ34pFlg2MaLnKJZ4fizb_rvs2zL1C2tPsgWdSmrqI4-SQubqdw4UmrBdvusSCdr--Tu3NJDAITo8ymf7Hns086OMKZR-f_5CKv63jCySgXHLZrfjCA22jHsx7g6tw2EVW72NejAP3znaAkWbvx8zJzZUBw8v3kvE
# ...

# %%
r["stateHandle"] == r['remediation']["value"][0]["value"][1]["value"]
# Out:
# True

# %%
def post_identify(email, state_token):
    url = "https://id.meijer.com/idp/idx/identify"

    headers = {
        "accept": "application/json; okta-version=1.0.0",
        "x-okta-user-agent-extended": "okta-auth-js/7.11.0 okta-signin-widget-g3-7.29.1-g5868685",
        "x-device-fingerprint": "wlb-qUfcJ1u6_NxvtpVUlmyDhRPra-JK|6ef83fe94ab0c8a5237c33202c9c5e635074bbce21fc482bc239bf962a0c2c25|21c0dae824c3f48f32f5b271e1d291d8",
        "user-agent": "Mozilla/5.0 (Linux; Android 10; K) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.0.0 Mobile Safari/537.36",
        "content-type": "application/json",
        "origin": "https://id.meijer.com",
        "x-requested-with": "com.duckduckgo.mobile.android",
        "sec-fetch-site": "same-origin",
        "sec-fetch-mode": "cors",
        "sec-fetch-dest": "empty",
        "accept-encoding": "gzip, deflate",
        "accept-language": "en-US,en;q=0.9",
    }

    payload = {
        "identifier": email,
        "stateHandle": state_token
    }


    response = requests.post(url, headers=headers, json=payload)
    return response

# %%
response = post_identify("madson@unsuzu.xyz", r["stateHandle"])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 response = post_identify("madson@unsuzu.xyz", r["stateHandle"])
#
# Cell In[10], line 25, in post_identify(email, state_token)
#       4 headers = {
#       5     "accept": "application/json; okta-version=1.0.0",
#       6     "x-okta-user-agent-extended": "okta-auth-js/7.11.0 okta-signin-widget-g3-7.29.1-g5868685",
#    (...)     16     "accept-language": "en-US,en;q=0.9",
#      17 }
#      19 payload = {
#      20     "identifier": email,
#      21     "stateHandle": state_token
#      22 }
# ---> 25 response = requests.post(url, headers=headers, json=payload)
#      26 return response
#
# File /projects/python_Meijer/venv/lib/python3.12/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
# ...

# %%
import requests

url = "https://id.meijer.com/idp/idx/identify"

headers = {
    "accept": "application/json; okta-version=1.0.0",
    "x-okta-user-agent-extended": "okta-auth-js/7.11.0 okta-signin-widget-g3-7.29.4-g9a623b8",
    "user-agent": "Mozilla/5.0 (Linux; Android 10; K) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.0.0 Mobile Safari/537.36",
    "content-type": "application/json",
    "origin": "https://id.meijer.com",
    "x-requested-with": "com.duckduckgo.mobile.android",
    "sec-fetch-site": "same-origin",
    "sec-fetch-mode": "cors",
    "sec-fetch-dest": "empty",
    "accept-encoding": "gzip, deflate",
    "accept-language": "en-US,en;q=0.9",
    "cookie": "DT=DI1OFou47yTRzKlaqWNbgT_Sg; AMCVS_A8643BC75245AF510A490D4D%40AdobeOrg=1; digitalID=; s_tp=8227; s_ppv=Meijer%2520Credit%2520Cards%2520%257C%2520Meijer%2C10%2C10%2C841; s_cc=true; luf_2116002385=...; ln=meijer.com@eabi.xyz; luf_-1100226894=...; AKA_A2=A; ak_bmsc=...; bm_sz=...; _abck=...; JSESSIONID=...; bm_mi=...; bm_sv=..."
}

payload = {
    "identifier": "meijer.com@eabi.xyz",
    "stateHandle": r["stateHandle"]
}

response = requests.post(url, headers=headers, json=payload)

print(response.status_code)
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 25
#       5 headers = {
#       6     "accept": "application/json; okta-version=1.0.0",
#       7     "x-okta-user-agent-extended": "okta-auth-js/7.11.0 okta-signin-widget-g3-7.29.4-g9a623b8",
#    (...)     17     "cookie": "DT=DI1OFou47yTRzKlaqWNbgT_Sg; AMCVS_A8643BC75245AF510A490D4D%40AdobeOrg=1; digitalID=; s_tp=8227; s_ppv=Meijer%2520Credit%2520Cards%2520%257C%2520Meijer%2C10%2C10%2C841; s_cc=true; luf_2116002385=...; ln=meijer.com@eabi.xyz; luf_-1100226894=...; AKA_A2=A; ak_bmsc=...; bm_sz=...; _abck=...; JSESSIONID=...; bm_mi=...; bm_sv=..."
#      18 }
#      20 payload = {
#      21     "identifier": "meijer.com@eabi.xyz",
#      22     "stateHandle": r["stateHandle"]
#      23 }
# ---> 25 response = requests.post(url, headers=headers, json=payload)
#      27 print(response.status_code)
# ...

# %%
raw_request = """
POST https://id.meijer.com/idp/idx/identify HTTP/2.0
content-length: 4174
accept: application/json; okta-version=1.0.0
x-okta-user-agent-extended: okta-auth-js/7.11.0 okta-signin-widget-g3-7.29.4-g9a623b8
user-agent: Mozilla/5.0 (Linux; Android 10; K) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.0.0 Mobile Safari/537.36
content-type: application/json
origin: https://id.meijer.com
x-requested-with: com.duckduckgo.mobile.android
sec-fetch-site: same-origin
sec-fetch-mode: cors
sec-fetch-dest: empty
accept-encoding: gzip, deflate
accept-language: en-US,en;q=0.9
cookie: DT=DI1OFou47yTRzKlaqWNbgT_Sg
cookie: AMCVS_A8643BC75245AF510A490D4D%40AdobeOrg=1
cookie: digitalID=
cookie: s_tp=8227
cookie: s_ppv=Meijer%2520Credit%2520Cards%2520%257C%2520Meijer%2C10%2C10%2C841
cookie: s_cc=true
cookie: luf_2116002385=eyJ6aXAiOiJERUYiLCJ2ZXIiOiIxIiwiYWxpYXMiOiJlbmNyeXB0aW9ua2V5Iiwib2lkIjoiMDBvZW14bng4Q3NocE5WeVM2OTYiLCJlbmMiOiJBMjU2R0NNIiwiYWxnIjo
RaIuBhvXOZ3IX68J9wI4hGMbpeW9K26EspzsEZW5euaE39KQz32ouhxaumPSuvI4lFo8oJdJy419yUYK9A-NRNpDwX5q1SGWUcNo9VBxTqQsoSgOm8PrXBegbRFs9Zd5JiBFFVKi_wFoBl3Vtz_llHqvgvLS5XUbrzaiDnGi0VpzCZ7Fnszj4dXR9dkVVkRMElHIcv6Uol8NEBOts4F2PJ_cv8M-vVA3YMZ-JYnP51J2q-luGc-uD1fEFuKP1sCDZP1MFYU3M31-cjIU3_Gdn8QaPSuwH6aiHiKqpJYCkxgvBsa5ffayAcpcLjs383xS9h3tng7hSLn9p1LC-xyRNApwONEh-5P96n8TrcUxawzIZ5aYR-3Uv2MrhKWZOmx8rfD-rcivfIGJ5AjPTYLf7tUxXwvR.IcTo62sJR1-ectO-fJvfXQ"}
"""

cookie_lines = [line.strip().split("cookie: ", 1)[1] for line in raw_request.splitlines() if line.strip().lower().startswith("cookie:")]
cookie_header = "; ".join(cookie_lines)

# %%
cookie_header
# Out:
# 'DT=DI1OFou47yTRzKlaqWNbgT_Sg; AMCVS_A8643BC75245AF510A490D4D%40AdobeOrg=1; digitalID=; s_tp=8227; s_ppv=Meijer%2520Credit%2520Cards%2520%257C%2520Meijer%2C10%2C10%2C841; s_cc=true; luf_2116002385=eyJ6aXAiOiJERUYiLCJ2ZXIiOiIxIiwiYWxpYXMiOiJlbmNyeXB0aW9ua2V5Iiwib2lkIjoiMDBvZW14bng4Q3NocE5WeVM2OTYiLCJlbmMiOiJBMjU2R0NNIiwiYWxnIjoiZGlyIiwidGltZXN0YW1wIjoxNzQyNzcwNTA4Njg2fQ..pXeyj6eu_H-POg1G.u4nFnXv3myu57kB0hesAQQUT9Rl_C-JIJgoFbRgh68L9rAV7jA8Bxtp9I4WcE2-CCuOB4kwURkWUZwTIFKQOpzecsJqdWP8eMn4AX1txwLRxkh-fcmWXzNDxAMuq-3ZXKNPgjNsTa-CxigaIxgqJNM4uKxjdT3p7AOUUObIAIE16jL-Agn3j9tnGVb7k0TreLrwi8lNrXw.Jr6T_VS0tRZOzQ2UejS-pw; ln=meijer.com@eabi.xyz; luf_-1100226894=eyJ6aXAiOiJERUYiLCJ2ZXIiOiIxIiwiYWxpYXMiOiJlbmNyeXB0aW9ua2V5Iiwib2lkIjoiMDBvZW14bng4Q3NocE5WeVM2OTYiLCJlbmMiOiJBMjU2R0NNIiwiYWxnIjoiZGlyIiwidGltZXN0YW1wIjoxNzQzODg3MjAxMDM5fQ..o3Gmw3A--QXL445P.C2oSLuGCe7OGCavJhIsXWkNLUWQozYS9oXjzHWBL7LiuTfyWX_W_Rn4B3N8qqb8Za6V5Y4d1fLffxWnddQCn1AsKY4Eq97k9NQf6TLKUK__Ok3LTU2Y489ZpvOhAoliKBDCRuIvvPj_-X8UedCd8
# ...

# %%
response = requests.post(url, headers=cookie_header, json=payload)

print(response.status_code)
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 response = requests.post(url, headers=cookie_header, json=payload)
#       3 print(response.status_code)
#       4 print(response.text)
#
# File /projects/python_Meijer/venv/lib/python3.12/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)    112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File /projects/python_Meijer/venv/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
# ...
